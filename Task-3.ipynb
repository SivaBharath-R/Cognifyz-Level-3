# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('Dataset .csv')

# %%
x1=df['Has Online delivery']
y= df['Average Cost for two']
x2= df['Has Table booking']

# %%
plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
sns.boxplot(x=x1,y=y)
plt.xlabel('Online Delivery')
plt.ylabel('Average Cost For Two')
plt.title('Online Delivery Affected By Cost')
plt.subplot(1,2,2)
sns.boxplot(x=x2,y=y)
plt.xlabel('Table booking')
plt.ylabel('Average Cost For Two')
plt.title('Table booking  Affected By Cost')
plt.tight_layout()
plt.show()

# %%
print('both the online delivery and table booking are negatively impacting by the cost')
# Out:
# both the online delivery and table booking are negatively impacting by the cost

# %%
'''Determine if higher-priced restaurants are
more likely to offer these services.'''

# %%
print('high priced restaurants which have average cost more than 10,000 did not provide online delivery as well as table booking fecilities')
# Out:
# high priced restaurants which have average cost more than 10,000 did not provide online delivery as well as table booking fecilities

# %%
plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
sns.boxplot(x=x1,y='Average Cost for two',data = df.loc[df['Average Cost for two'] < 10000])
plt.title('Online delivery by cost')
plt.subplot(1,2,2)
sns.boxplot(x=x2,y='Average Cost for two',data = df.loc[df['Average Cost for two'] < 10000])
plt.title('Table booking  by Cost')
plt.tight_layout()
plt.show()
